# %%
import torch

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# 2.1.2
# True
# NVIDIA GeForce RTX 4090

# %%
# !nvidia-smi -q > /app/results/gpu_info/nvidia_smi_q.txt

# %%
# !ls -lh /app/results/gpu_info/
# Out:
# total 16K
# -rw-r--r-- 1 root root 15K Sep 15 21:13 nvidia_smi_q.txt

# %%
# !nvidia-smi --query-gpu=name,uuid,driver_version,memory.total,power.limit --format=csv
# Out:
# name, uuid, driver_version, memory.total [MiB], power.limit [W]
# NVIDIA GeForce RTX 4090, GPU-3094e1cd-3205-910b-9555-93d8401b1ce0, 610.60, 24564 MiB, 450.00 W

# %%
print("PyTorch version:", torch.__version__)
print("CUDA version used by PyTorch:", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())
# Out:
# PyTorch version: 2.1.2
# CUDA version used by PyTorch: 12.1
# cuDNN version: 8902

# %%
# !nvidia-smi --query-gpu=name,uuid,driver_version,memory.total,power.limit --format=csv
# Out:
# name, uuid, driver_version, memory.total [MiB], power.limit [W]
# NVIDIA GeForce RTX 4090, GPU-3094e1cd-3205-910b-9555-93d8401b1ce0, 610.60, 24564 MiB, 450.00 W

# %%
# !nvidia-smi -q > /app/results/gpu_info/nvidia_smi_q.txt

# %%
# !ls -lh /app/results/gpu_info/
# Out:
# total 16K
# -rw-r--r-- 1 root root 15K Sep 15 21:15 nvidia_smi_q.txt

# %%
with open("/app/results/gpu_info/software_stack.txt", "w") as f:
    f.write(f"PyTorch version: {torch.__version__}\n")
    f.write(f"CUDA version used by PyTorch: {torch.version.cuda}\n")
    f.write(f"cuDNN version: {torch.backends.cudnn.version()}\n")
    f.write(f"GPU: {torch.cuda.get_device_name(0)}\n")
    f.write("GPU UUID: GPU-3094e1cd-3205-910b-9555-93d8401b1ce0\n")

# %%
# !cat /app/results/gpu_info/software_stack.txt
# Out:
# PyTorch version: 2.1.2
# CUDA version used by PyTorch: 12.1
# cuDNN version: 8902
# GPU: NVIDIA GeForce RTX 4090
# GPU UUID: GPU-3094e1cd-3205-910b-9555-93d8401b1ce0

# %%
# !nvidia-smi -q > /app/results/gpu_info/nvidia_smi_q.txt

# %%
# !ls -lh /app/results/gpu_info/
# Out:
# total 16K
# -rw-r--r-- 1 root root 15K Sep 15 21:16 nvidia_smi_q.txt
# -rw-r--r-- 1 root root 158 Sep 15 21:15 software_stack.txt
